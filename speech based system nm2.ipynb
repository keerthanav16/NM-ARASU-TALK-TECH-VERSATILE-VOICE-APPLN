# %%
# !pip install SpeechRecognition pydub
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.9/32.9 MB 14.0 MB/s eta 0:00:00
# ...

# %%
import speech_recognition as sr
import csv
import os

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-9b1b3e61-8416-45fd-89be-61a05dfe55ea" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9b1b3e61-8416-45fd-89be-61a05dfe55ea">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
filename = list(uploaded.keys())[0]
print("✅ File uploaded:", filename)
# Out:
# ✅ File uploaded: data_entry.wav.wav

# %%
import speech_recognition as sr
import csv

def data_entry_transcription(audio_file_path, csv_filename="data_entry.csv"):
    recognizer = sr.Recognizer()

    try:
        with sr.AudioFile(audio_file_path) as source:
            print(f"🔊 Loading audio file: {audio_file_path}")
            audio = recognizer.record(source)

            # Transcribe using Google Speech API
            text = recognizer.recognize_google(audio)
            print("\n📝 Data Entry Transcribed Text:\n")
            print(text)

            # Save the transcribed text to CSV (as a new entry)
            with open(csv_filename, mode='a', newline='') as file:
                writer = csv.writer(file)
                writer.writerow([text])  # Add the transcribed text to a new row

            print(f"✅ Transcription saved to {csv_filename}")
            return text

    except FileNotFoundError:
        print("❌ File not found. Please check the path.")
    except sr.UnknownValueError:
        print("❌ Could not understand the audio.")
    except sr.RequestError as e:
        print(f"⚠️ Request error from API: {e}")
    return None

# Replace with your actual file name
data_entry_transcription("data_entry.wav.wav")
# Out:
# 🔊 Loading audio file: data_entry.wav.wav
#
# 📝 Data Entry Transcribed Text:
#
# name of the student is John and he's on the stadium on the engineering third year at Harrison engineering college and his age is 31 + 21 + 4 + 1,800
# ✅ Transcription saved to data_entry.csv
# "name of the student is John and he's on the stadium on the engineering third year at Harrison engineering college and his age is 31 + 21 + 4 + 1,800"

# %%
from google.colab import files
files.download("data_entry.csv")
